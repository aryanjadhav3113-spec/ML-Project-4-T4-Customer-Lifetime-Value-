# %%
# importing the libraries
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# lets read the Data set
data=pd.read_excel(r'C:\Users\Aryan\OneDrive\Desktop\Copy of Online Retail.xlsx')

# print the shape of the dataset
print("Shape of the Dataset:",data.shape)
# Out:
# Shape of the Dataset: (541909, 8)

# %%
# lets check the columns name of the dataset
data.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %% [markdown]
# #  find out the patterrn in Transactions when the usr was foreigner

# %%
# lets check the value counts for country
data['Country'].value_counts()
# Out:
# Country
# United Kingdom          495478
# Germany                   9495
# France                    8557
# EIRE                      8196
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               2002
# Portugal                  1519
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Unspecified                446
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     297
# USA                        291
# Hong Kong                  288
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# ...

# %%
# lets first create a dataset for foreign customers
# As most of the Customers are from UK,so all the customers except UK,are foreign Customers
data[data['Country'] !='United Kingdom'][['Quantity','UnitPrice']].describe()
# Out:
#            Quantity     UnitPrice
# count  46431.000000  46431.000000
# mean      19.655424      5.450852
# std       47.233708     63.360527
# min     -624.000000      0.000000
# 25%        4.000000      1.250000
# 50%       10.000000      1.950000
# 75%       16.000000      3.750000
# max     2400.000000   4161.060000

# %% [markdown]
# # check the descriptions for customers who bought items in higher quantities

# %%
# lets check the Distribution of Quantity
sns.distplot(data['Quantity'])

# filtering customers who purchased more than 10000 Items and checking their Descriptions
data[data['Quantity']>10000][['Description','Quantity','Country']]
# Out:
# C:\Users\Aryan\AppData\Local\Temp\ipykernel_7548\1473994324.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Quantity'])
#                            Description  Quantity         Country
# 61619   MEDIUM CERAMIC TOP STORAGE JAR     74215  United Kingdom
# 502122  ASSTD DESIGN 3D PAPER STICKERS     12540  United Kingdom
# 540421     PAPER CRAFT , LITTLE BIRDIE     80995  United Kingdom
